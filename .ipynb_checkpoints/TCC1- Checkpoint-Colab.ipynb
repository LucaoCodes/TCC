# %% [markdown]
# #Bibliotecas

# %%
# !pip install yfinance pandas-datareader statsmodels plotly python-bcb openpyxl ipeadatapy pygam --quiet

# %%
# Bibliotecas
from bcb import sgs
from bcb import Expectativas
import yfinance as yf
import pandas as pd
import pandas_datareader.data as web
import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests, adfuller, kpss
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.vector_ar.var_model import VAR
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.gam.api import GLMGam, BSplines
import statsmodels.formula.api as smf
from scipy import stats
import plotly.express as px
import requests
from io import BytesIO
import seaborn as sns
import matplotlib.pyplot as plt
import ipeadatapy as ipea
from google.colab import sheets
import numpy as np
import warnings
from pygam import LinearGAM, s, l
#from fredapi import Fred

# %% [markdown]
# #Coleta de dados

# %%
selic_00_09 = sgs.get({'br_selic': 11}, start='2000-01-01', end='2009-12-31')
selic_10_19 = sgs.get({'br_selic': 11}, start='2010-01-01', end='2019-12-31')
selic_20_24 = sgs.get({'br_selic': 11}, start='2020-01-01', end='2024-12-31')
br_selic = pd.concat([selic_00_09, selic_10_19, selic_20_24])
br_selic = br_selic.sort_index()
br_selic.columns = ['br_selic']

# %%
print(br_selic.head())
print(br_selic.describe())
print(br_selic.isnull().sum())
# Out:
#             br_selic
# Date
# 2000-01-03  0.069186
# 2000-01-04  0.069186
# 2000-01-05  0.069220
# 2000-01-06  0.069286
# 2000-01-07  0.069286
#           br_selic
# count  6279.000000
# mean      0.045347
# std       0.017557
# min       0.007469
# 25%       0.033784
# 50%       0.044698
# 75%       0.056683
# max       0.092855
# br_selic    0
# dtype: int64

# %%
dolar_00_09 = sgs.get({'br_dolar': 1}, start='2000-01-01', end='2009-12-31')
dolar_10_19 = sgs.get({'br_dolar': 1}, start='2010-01-01', end='2019-12-31')
dolar_20_24 = sgs.get({'br_dolar': 1}, start='2020-01-01', end='2024-12-31')
br_dolar = pd.concat([dolar_00_09, dolar_10_19, dolar_20_24])
br_dolar = br_dolar.sort_index()
br_dolar.columns = ['br_dolar']

# %%
print(br_dolar.head())
print(br_dolar.describe())
print(br_dolar.isnull().sum())
# Out:
#             br_dolar
# Date
# 2000-01-03    1.8011
# 2000-01-04    1.8337
# 2000-01-05    1.8544
# 2000-01-06    1.8461
# 2000-01-07    1.8281
#           br_dolar
# count  6279.000000
# mean      3.085083
# std       1.259003
# min       1.534500
# 25%       2.034100
# 50%       2.726400
# 75%       3.862550
# max       6.199100
# br_dolar    0
# dtype: int64

# %%
# IDs utilizados pelo SGS
series_ids = {
    'br_ipca': 433,# IPCA (inflação)
    'br_pib': 4380,# PIB (Trimestral)
    #'br_cambio_dolar': 3695, #Cambio(Dolar)
}

df_brasil = sgs.get(list(series_ids.values()), start='2000-01-01', end='2024-12-31') #Extraindo com o periodo desejado
df_brasil.columns = series_ids.keys()
df_brasil.head()
# Out:
#             br_ipca   br_pib
# Date
# 2000-01-01     0.62  92576.6
# 2000-02-01     0.13  91770.4
# 2000-03-01     0.22  92579.9
# 2000-04-01     0.42  91376.2
# 2000-05-01     0.01  98727.0

# %%
# --- Bloco de Expectativas (Nível Diário) ---
expectativas = Expectativas()
data_inicio = '2000-01-01'
data_fim = '2024-12-31'
ep_mensais = expectativas.get_endpoint('ExpectativaMercadoMensais')

consulta = ep_mensais.query() \
        .filter(ep_mensais.Indicador == 'IPCA') \
        .filter(ep_mensais.Data >= data_inicio, ep_mensais.Data <= data_fim) \
        .collect()
df = pd.DataFrame(consulta)

# Tratamento para obter a expectativa para 12 meses à frente, em base diária
df['Data'] = pd.to_datetime(df['Data'])
df['DataReferencia'] = pd.to_datetime(df['DataReferencia'], format='mixed')

# Para cada data de pesquisa, calculamos qual seria o mês de referência alvo (12 meses à frente)
df['MesPesquisa'] = df['Data'].dt.to_period('M').dt.to_timestamp()
df['MesAlvo12M'] = df['MesPesquisa'] + pd.DateOffset(months=12)

# Filtramos o DataFrame, mantendo apenas as previsões para o alvo de 12 meses
df_12m = df[df['DataReferencia'] == df['MesAlvo12M']].copy()

# Para cada dia de pesquisa, pegamos o último valor reportado.
df_final = df_12m.sort_values('Data').drop_duplicates(subset=['Data'], keep='last')

# Selecionamos as colunas e definimos o índice
df_final_exp = df_final[['Data', 'Media']].rename(columns={'Media': 'ipca_expectativa'})
df_final_exp = df_final_exp.set_index('Data')
df_final_exp.head()
# Out:
#             ipca_expectativa
# Data
# 2001-11-06              0.34
# 2001-11-07              0.31
# 2001-11-08              0.32
# 2001-11-09              0.31
# 2001-11-12              0.32

# %%
# IDs utilizados pelo yahoo finance BR
series_ids_yf_br = {
    'br_ibov': '^BVSP',#Ibovespa
    #'br_ewz': 'EWZ',#ewz (a partir do mes 7 apenas)
}

tickers = list(series_ids_yf_br.values())
df_br_yf = yf.download(tickers, start='2000-01-01', end='2024-12-31')['Close']
ticker_map = {v: k for k, v in series_ids_yf_br.items()}
df_br_yf.columns = [ticker_map.get(col, col) for col in df_br_yf.columns]

display(df_br_yf.head())
# Out:
# /tmp/ipython-input-9-641301814.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_br_yf = yf.download(tickers, start='2000-01-01', end='2024-12-31')['Close']
# [*********************100%***********************]  1 of 1 completed
#             br_ibov
# Date
# 2000-01-03  16930.0
# 2000-01-04  15851.0
# 2000-01-05  16245.0
# 2000-01-06  16107.0
# 2000-01-07  16309.0

# %%
#Metrica risco-pais
codigo_embi = 'JPM366_EMBI366'

# Busca a série temporal completa
embi_brasil = ipea.timeseries(codigo_embi)

# A função ipea.timeseries retorna um DataFrame com um MultiIndex.
embi_brasil = embi_brasil['VALUE (-)'].to_frame(name='embi_brasil')

# Filtragem de data
start_date = '2000-01-01'
embi_brasil = embi_brasil[embi_brasil.index >= start_date]

embi_brasil.head()
# Out:
#             embi_brasil
# DATE
# 2000-01-01          NaN
# 2000-01-02          NaN
# 2000-01-03        626.0
# 2000-01-04        675.0
# 2000-01-05        677.0

# %% [markdown]
# ##Consolidação e Analise Incial

# %%
#juntando bases
br_full = pd.concat([br_selic, br_dolar, df_brasil, df_br_yf, embi_brasil, df_final_exp], axis=1)
br_full.head()
# Out:
#             br_selic  br_dolar  br_ipca   br_pib  br_ibov  embi_brasil  \
# 2000-01-01       NaN       NaN     0.62  92576.6      NaN          NaN
# 2000-01-02       NaN       NaN      NaN      NaN      NaN          NaN
# 2000-01-03  0.069186    1.8011      NaN      NaN  16930.0        626.0
# 2000-01-04  0.069186    1.8337      NaN      NaN  15851.0        675.0
# 2000-01-05  0.069220    1.8544      NaN      NaN  16245.0        677.0
#
#             ipca_expectativa
# 2000-01-01               NaN
# 2000-01-02               NaN
# 2000-01-03               NaN
# 2000-01-04               NaN
# 2000-01-05               NaN

# %%
#analise basica df
print("Informações gerais da base:\n")
print(f"Linha/Coluna: {br_full.shape}")
print("\nTipos de dados:")
print(br_full.dtypes)

print("\n Valores nulos por coluna:")
print(br_full.isnull().sum())

print("\nEstatísticas descritivas:")
display(br_full.describe())
# Out:
# Informações gerais da base:
#
# Linha/Coluna: (8218, 7)
#
# Tipos de dados:
# br_selic            float64
# br_dolar            float64
# br_ipca             float64
# br_pib              float64
# br_ibov             float64
# embi_brasil         float64
# ipca_expectativa    float64
# dtype: object
#
#  Valores nulos por coluna:
# br_selic            1939
# br_dolar            1939
# br_ipca             7918
# br_pib              7918
# br_ibov             2027
# embi_brasil         1883
# ipca_expectativa    2407
# dtype: int64
#
# Estatísticas descritivas:
#           br_selic     br_dolar     br_ipca        br_pib        br_ibov  \
# count  6279.000000  6279.000000  300.000000  3.000000e+02    6191.000000
# mean      0.045347     3.085083    0.501133  4.274779e+05   60859.276207
# std       0.017557     1.259003    0.394905  2.559445e+05   34525.789157
# min       0.007469     1.534500   -0.680000  9.137620e+04    8371.000000
# ...

# %% [markdown]
# #Tratando os Dados

# %%
# Interpolar primeiro as séries de baixa frequência (IPCA e PIB)
# Criamos um índice diário completo para o período e depois interpolamos.
indice_diario_completo = pd.date_range(start=df_brasil.index.min(), end=df_brasil.index.max(), freq='D')
df_brasil_interpolado = df_brasil.reindex(indice_diario_completo).interpolate(method='linear')
df_brasil_interpolado.head()
# Out:
#              br_ipca        br_pib
# 2000-01-01  0.620000  92576.600000
# 2000-01-02  0.604194  92550.593548
# 2000-01-03  0.588387  92524.587097
# 2000-01-04  0.572581  92498.580645
# 2000-01-05  0.556774  92472.574194

# %%
# Definir o índice mestre com os dias de negociação do Ibovespa
# Usamos o 'br_ibov' como referência de dias úteis.
df_diario = pd.DataFrame(index=df_br_yf.index)

# Juntar todas as séries de dados ao índice mestre
# Agora usamos o df_brasil_interpolado, que já está em frequência diária.
df_diario = pd.concat([
    df_br_yf,
    br_selic,
    br_dolar,
    df_brasil_interpolado, # base já interpolada
    df_final_exp,
    embi_brasil
], axis=1)

# Remove quaisquer linhas no início que ainda possam ser nulas (final de semana e inicio)
df_diario = df_diario.dropna()

# %%
df_diario.head()
# Out:
#             br_ibov  br_selic  br_dolar  br_ipca         br_pib  \
# 2001-11-06  12416.0  0.069186    2.6003    0.700  117071.116667
# 2001-11-07  12616.0  0.069220    2.6055    0.698  116908.940000
# 2001-11-08  12554.0  0.069186    2.5571    0.696  116746.763333
# 2001-11-09  12731.0  0.069186    2.5347    0.694  116584.586667
# 2001-11-12  12567.0  0.069220    2.5502    0.688  116098.056667
#
#             ipca_expectativa  embi_brasil
# 2001-11-06              0.34       1123.0
# 2001-11-07              0.31       1083.0
# 2001-11-08              0.32       1054.0
# 2001-11-09              0.31       1054.0
# 2001-11-12              0.32       1074.0

# %%
# Análise Brasil Transformada
# Calcula a matriz de correlação
matriz_corr = df_diario.corr()

# Cria o mapa de calor usando seaborn
plt.figure(figsize=(16, 12))
sns.heatmap(
    matriz_corr,
    annot=True,
    annot_kws={'size': 20},
    cmap='coolwarm',
    fmt='.2f',
    linewidths=.5
)
plt.xticks(fontsize=15, rotation=45, ha='right')
plt.yticks(fontsize=15, rotation=-45)
plt.tight_layout() # Adicionado para melhor ajuste do gráfico
plt.show()

# %% [markdown]
# ##Analise Dados Tratados

# %%
# Cria uma figura com dois subplots (1 linha, 2 colunas)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(28, 12))

# Define a ordem das variáveis com base no DataFrame original
ordem_original = br_full.columns.tolist()
ordem_tratada = df_diario.columns.tolist()


# Mapa de Calor 1: Séries Originais (br_full)
# Calcula a correlação e reordena para garantir a ordem
matriz_corr_original = br_full.corr().reindex(index=ordem_original, columns=ordem_original)
sns.heatmap(matriz_corr_original, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5, ax=axes[0])
axes[0].set_title('Mapa de Calor - Séries Originais (em Nível)', fontsize=16)

# Mapa de Calor 2: Séries Transformadas (df_diario)
# Calcula a correlação e reordena para corresponder à ordem
matriz_corr_transformada = df_diario.corr().reindex(index=ordem_tratada, columns=ordem_tratada)
sns.heatmap(matriz_corr_transformada, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5, ax=axes[1])
axes[1].set_title('Mapa de Calor - Séries Tratadas', fontsize=16)


fig.suptitle('Comparação das Matrizes de Correlação', fontsize=20)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# #Teste de Estacionaridade Dados Tratados

# %%
def rodar_testes_estacionariedade(df):
    resultados = []
    print("\nRodando testes de estacionariedade...")
    for coluna in df.columns:
        try:
            teste_adf = adfuller(df[coluna].dropna())
            p_valor_adf = teste_adf[1]
            teste_kpss = kpss(df[coluna].dropna(), regression='c', nlags="auto")
            p_valor_kpss = teste_kpss[1]
            resultados.append({'Variável': coluna, 'P-valor ADF': p_valor_adf, 'P-valor KPSS': p_valor_kpss})
        except Exception as e:
            resultados.append({'Variável': coluna, 'P-valor ADF': f"Erro: {e}", 'P-valor KPSS': f"Erro: {e}"})
    df_resultados = pd.DataFrame(resultados)
    return df_resultados.set_index('Variável')

# Roda os testes na base de dados em nível (já tratada)
resultados_estacionariedade = rodar_testes_estacionariedade(df_diario)
print("\n--- Resultados dos Testes de Estacionariedade (Séries em Nível) ---")
display(resultados_estacionariedade)
# Out:
# Rodando testes de estacionariedade...
# /tmp/ipython-input-18-3030415670.py:8: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   teste_kpss = kpss(df[coluna].dropna(), regression='c', nlags="auto")
# /tmp/ipython-input-18-3030415670.py:8: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   teste_kpss = kpss(df[coluna].dropna(), regression='c', nlags="auto")
# /tmp/ipython-input-18-3030415670.py:8: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   teste_kpss = kpss(df[coluna].dropna(), regression='c', nlags="auto")
# ...

# %% [markdown]
# #Transformando dados Não Estacionarios

# %%
# Criando uma nova base de dados para as séries transformadas
br_transformado = pd.DataFrame(index=df_diario.index)

# Aplicando as transformações
for coluna in df_diario.columns:
    # Copia a coluna do IPCA diretamente, pois já é estacionária
    if 'br_ipca' == coluna:
        br_transformado[coluna] = df_diario[coluna]
    # Para séries de preços ou índices, usamos o retorno logarítmico
    elif 'ibov' in coluna.lower() or 'pib' in coluna.lower() or 'ewz' in coluna.lower():
        br_transformado[f'{coluna}_ret_log'] = np.log(df_diario[coluna]).diff()
    # Para as outras métricas, usamos a primeira diferença
    else:
        br_transformado[f'{coluna}_diff'] = df_diario[coluna].diff()

# Remove a primeira linha que será NaN após a diferenciação
br_transformado = br_transformado.dropna()

print("\n--- Base de Dados Brasileira Transformada (Diferenciada) ---")
display(br_transformado.head())

# Agora, rodamos os testes de estacionariedade novamente na base transformada
print("\n--- Testando a Estacionariedade da Base Transformada ---")
resultados_transformado = rodar_testes_estacionariedade(br_transformado)
display(resultados_transformado)
# Out:
# --- Base de Dados Brasileira Transformada (Diferenciada) ---
#             br_ibov_ret_log  br_selic_diff  br_dolar_diff  br_ipca  \
# 2001-11-07         0.015980       0.000034         0.0052    0.698
# 2001-11-08        -0.004927      -0.000034        -0.0484    0.696
# 2001-11-09         0.014001       0.000000        -0.0224    0.694
# 2001-11-12        -0.012966       0.000034         0.0155    0.688
# 2001-11-13         0.027547       0.000000        -0.0232    0.686
#
#             br_pib_ret_log  ipca_expectativa_diff  embi_brasil_diff
# 2001-11-07       -0.001386                  -0.03             -40.0
# 2001-11-08       -0.001388                   0.01             -29.0
# 2001-11-09       -0.001390                  -0.01               0.0
# 2001-11-12       -0.004182                   0.01              20.0
# 2001-11-13       -0.001398                   0.01             -64.0
# --- Testando a Estacionariedade da Base Transformada ---
#
# ...

# %%
# Análise Brasil Transformada
# Calcula a matriz de correlação
matriz_corr = br_transformado.corr()

# Cria o mapa de calor usando seaborn
plt.figure(figsize=(16, 12))
sns.heatmap(
    matriz_corr,
    annot=True,
    annot_kws={'size': 20},
    cmap='coolwarm',
    fmt='.2f',
    linewidths=.5
)
plt.xticks(fontsize=15, rotation=45, ha='right')
plt.yticks(fontsize=15, rotation=-45)
plt.tight_layout() # Adicionado para melhor ajuste do gráfico
plt.show()

# %% [markdown]
# #Analise ACF e PACF

# %%
# Preparação dos Dados para analise ACF e PACF
# Usaremos o DataFrame 'br_transformado' da fase anterior.
# A nossa variável alvo é o retorno logarítmico do Ibovespa.
alvo_col_name = None
for col in br_transformado.columns:
    if 'ibov' in col and 'ret_log' in col:
        alvo_col_name = col
        break

serie_alvo = br_transformado[alvo_col_name].dropna()

# Teste com variaveis não transformadas
alvo_col_name2 = None
for col in df_diario.columns:
    if 'br_ibov' in col:
        alvo_col_name2 = col
        break

serie_alvo2 = df_diario[alvo_col_name2].dropna()

# %%
# 'd' (Diferenciação): Já sabemos que a série é estacionária, então d=0.
# 'p' (Ordem Autoregressiva) e 'q' (Ordem de Média Móvel): Usamos os gráficos ACF e PACF.

fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# --- Gráficos para a Série Original (em Nível) ---
plot_acf(serie_alvo2, ax=axes[0, 0], lags=40)
axes[0, 0].set_title('ACF da Série Original (Ibovespa em Nível)')

plot_pacf(serie_alvo2, ax=axes[0, 1], lags=40)
axes[0, 1].set_title('PACF da Série Original (Ibovespa em Nível)')

# --- Gráficos para a Série Transformada (Retornos) ---
plot_acf(serie_alvo, ax=axes[1, 0], lags=40)
axes[1, 0].set_title('ACF da Série Transformada (Retornos do Ibovespa)')

plot_pacf(serie_alvo, ax=axes[1, 1], lags=40)
axes[1, 1].set_title('PACF da Série Transformada (Retornos do Ibovespa)')

plt.tight_layout()
plt.show()

# %% [markdown]
# #Modelo ARIMA

# %%
# Busca Automática pelo Melhor Modelo ARIMA
# Como o modelo ARIMA(2,0,2) não passou na validação (teste de Ljung-Box),
# vamos automatizar a busca pela melhor combinação (p,q) usando o critério AIC.

# Define os limites para a busca de p e q
p_max = 5
q_max = 5
d = 0 # A série já é estacionária

# Ignora avisos de convergência durante a busca para manter o output limpo
warnings.filterwarnings("ignore")

melhor_aic = float("inf")
melhor_ordem = None
melhor_modelo = None

for p in range(p_max + 1):
    for q in range(q_max + 1):
        if p == 0 and q == 0:
            continue
        try:
            modelo_temp = ARIMA(serie_alvo, order=(p, d, q))
            resultado_temp = modelo_temp.fit()
            if resultado_temp.aic < melhor_aic:
                melhor_aic = resultado_temp.aic
                melhor_ordem = (p, d, q)
                melhor_modelo = resultado_temp
        except:
            continue

# Reativa os avisos
warnings.resetwarnings()

print(f"Melhor ordem: {melhor_ordem} \nAIC: {melhor_aic:.2f}")
# Out:
# Melhor ordem: (4, 0, 3)
# AIC: -29658.05

# %%
# Análise do Melhor Modelo
print(melhor_modelo.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:        br_ibov_ret_log   No. Observations:                 5598
# Model:                 ARIMA(4, 0, 3)   Log Likelihood               14838.024
# Date:                Wed, 16 Jul 2025   AIC                         -29658.048
# Time:                        22:40:38   BIC                         -29598.377
# Sample:                             0   HQIC                        -29637.254
#                                - 5598
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      1.830      0.067   -2.91e-05       0.001
# ar.L1         -0.7292      0.132     -5.517      0.000      -0.988      -0.470
# ar.L2          0.0329      0.194      0.170      0.865      -0.346       0.412
# ...

# %% [markdown]
# ##Analise de Residuos

# %%
# Validação do Melhor Modelo (Análise dos Resíduos)
residuos = melhor_modelo.resid

# Cria uma figura para os gráficos de validação
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# Gráfico 1: Resíduos ao longo do tempo
axes[0].plot(residuos)
axes[0].set_title('Resíduos do Melhor Modelo ARIMA ao Longo do Tempo')
axes[0].set_xlabel('Data')
axes[0].set_ylabel('Resíduo')

# Gráfico 2: Função de Autocorrelação (ACF) dos Resíduos
plot_acf(residuos, ax=axes[1], lags=40, title='ACF dos Resíduos')
axes[1].set_xlabel('Defasagens (Lags)')
axes[1].set_ylabel('Autocorrelação')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##Teste Ljung-Box

# %%
# Teste de Ljung-Box para autocorrelação dos resíduos:
# O objetivo é ter um p-valor (lb_pvalue) > 0.05
lags_teste = min(24, len(residuos)//5)
teste_ljung_box = sm.stats.acorr_ljungbox(residuos, lags=[lags_teste], return_df=True)
display(teste_ljung_box)
# Out:
#       lb_stat  lb_pvalue
# 24  27.295207   0.290882

# %% [markdown]
# #OLS

# %%
# Análise de Regressão Linear Múltipla (OLS)

# Preparar as variáveis para o modelo
# Variável Dependente (Y): o que queremos explicar.
y = br_transformado['br_ibov_ret_log']

# Variáveis Independentes (X): os fatores que usaramos para explicar Y.
# Vamos excluir a variável alvo e outras relacionadas ao Ibovespa para evitar redundância.
variaveis_explicativas = [col for col in br_transformado.columns if 'ibov' not in col]
X = br_transformado[variaveis_explicativas]

# É crucial adicionar uma constante (intercepto) ao modelo.
X = sm.add_constant(X)

print(X.columns.tolist())
# Out:
# ['const', 'br_selic_diff', 'br_dolar_diff', 'br_ipca', 'br_pib_ret_log', 'ipca_expectativa_diff', 'embi_brasil_diff']

# %%
# Estimação do Modelo OLS
modelo_ols = sm.OLS(y, X)
resultado_ols = modelo_ols.fit()
print(resultado_ols.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        br_ibov_ret_log   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.208
# Method:                 Least Squares   F-statistic:                     245.7
# Date:                Wed, 16 Jul 2025   Prob (F-statistic):          1.34e-279
# Time:                        22:40:38   Log-Likelihood:                 15478.
# No. Observations:                5598   AIC:                        -3.094e+04
# Df Residuals:                    5591   BIC:                        -3.090e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0009      0.000      2.591      0.010       0.000       0.002
# ...

# %% [markdown]
# ##Teste VIF

# %%
# Validação dos Pressupostos do Modelo

# Teste de Multicolinearidade (VIF)
# Mede se as variáveis independentes são correlacionadas entre si.
# Valores de VIF acima de 5 ou 10 são geralmente considerados um sinal de alerta.
vif_data = pd.DataFrame()
vif_data["Variável"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
display(vif_data)
# Out:
#                 Variável       VIF
# 0                  const  2.821625
# 1          br_selic_diff  1.009107
# 2          br_dolar_diff  1.143948
# 3                br_ipca  1.011924
# 4         br_pib_ret_log  1.003876
# 5  ipca_expectativa_diff  1.007564
# 6       embi_brasil_diff  1.144112

# %% [markdown]
# ##Teste Shapiro-Wiki

# %%
# Teste de Normalidade dos Resíduos (Shapiro-Wilk)
# H0: Os resíduos seguem uma distribuição normal.
# Queremos um p-valor > 0.05 para não rejeitar a normalidade.

residuos = resultado_ols.resid
shapiro_stat, shapiro_p_valor = stats.shapiro(residuos)
print(f"   - Estatística do teste: {shapiro_stat:.4f}")
print(f"   - P-valor: {shapiro_p_valor:.4f}")
if shapiro_p_valor < 0.05:
    print("   - Conclusão: Rejeita-se a hipótese de normalidade dos resíduos (comum em dados financeiros).")
else:
    print("   - Conclusão: Não se rejeita a hipótese de normalidade dos resíduos.")
# Out:
#    - Estatística do teste: 0.9553
#    - P-valor: 0.0000
#    - Conclusão: Rejeita-se a hipótese de normalidade dos resíduos (comum em dados financeiros).
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# ##Teste Breusch-Pagan

# %%
# Teste de Homocedasticidade dos Resíduos (Breusch-Pagan)
# H0: A variância dos resíduos é constante (homocedasticidade).
# Queremos um p-valor > 0.05 para não rejeitar a homocedasticidade.
bp_test = het_breuschpagan(residuos, resultado_ols.model.exog)
labels = ['Estatística LM', 'P-valor LM', 'Estatística F', 'P-valor F']
bp_df = pd.DataFrame(zip(labels, bp_test), columns=['Medida', 'Valor'])
display(bp_df)
if bp_test[1] < 0.05:
    print("   - Conclusão: Rejeita-se a hipótese de homocedasticidade (os erros são heterocedásticos).")
else:
    print("   - Conclusão: Não se rejeita a hipótese de homocedasticidade.")
# Out:
#            Medida         Valor
# 0  Estatística LM  7.702890e+01
# 1      P-valor LM  1.466040e-14
# 2   Estatística F  1.300099e+01
# 3       P-valor F  1.175302e-14
#    - Conclusão: Rejeita-se a hipótese de homocedasticidade (os erros são heterocedásticos).

# %%
br_transformado.to_csv('br_transformado.csv')
# Out:
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()

# %% [markdown]
# # GAM

# %%
# Definição das variáveis
y = br_transformado['br_ibov_ret_log']
features = br_transformado.columns.drop(['br_ibov_ret_log'])
X = br_transformado[features]

# %%
from pygam import LinearGAM, s
from sklearn.metrics import r2_score
# Out:
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()

# %%
# MODELO ADITIVO GENERALIZADO (GAM)
termos = s(0)
for i in range(1, X.shape[1]):
    termos += s(i)

# Treinamento do modelo com o DataFrame completo (X e y)
modelo_gam_completo = LinearGAM(termos, n_splines=15).fit(X, y)

# Avaliação do modelo no próprio conjunto de dados de treino
y_pred_gam_completo = modelo_gam_completo.predict(X)
r2_gam_completo = r2_score(y, y_pred_gam_completo)
print(f"\nPerformance do GAM no conjunto de dados completo (R-squared): {r2_gam_completo:.4f}")
# Out:
# Performance do GAM no conjunto de dados completo (R-squared): 0.2935

# %%
# --- CÓDIGO ADICIONADO: Exportar para Google Sheets ---
# Este bloco permite que você visualize e salve seu DataFrame em uma planilha Google.

# Instala as bibliotecas necessárias para a integração com o Google Sheets
# !pip install gspread gspread-dataframe --quiet

from google.colab import auth
import gspread
from gspread_dataframe import set_with_dataframe

# Autentica o usuário para permitir o acesso ao Google Drive/Sheets
print("\nAutenticando para acesso ao Google Sheets...")
auth.authenticate_user()
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)

# Cria ou abre uma nova planilha no seu Google Drive
# Você pode alterar o nome 'TCC_Dados_Brasileiros' como desejar.
nome_da_planilha = 'TCC_Dados_Brasileiros_Tratada'
print(f"Abrindo/Criando a planilha: '{nome_da_planilha}'...")
try:
    sh = gc.open(nome_da_planilha)
except gspread.exceptions.SpreadsheetNotFound:
    sh = gc.create(nome_da_planilha)

worksheet = sh.get_worksheet(0)

# Limpa a planilha antes de inserir novos dados
worksheet.clear()

# Converte o índice do DataFrame para uma coluna, pois o Google Sheets não tem índice
df_para_sheets = df_diario.reset_index()

# Converte colunas de data/período para string para evitar erros de formatação
for col in df_para_sheets.columns:
    if pd.api.types.is_period_dtype(df_para_sheets[col]):
        df_para_sheets[col] = df_para_sheets[col].astype(str)
    elif pd.api.types.is_datetime64_any_dtype(df_para_sheets[col]):
         df_para_sheets[col] = df_para_sheets[col].astype(str)

# Escreve o DataFrame na planilha
print("Escrevendo dados na planilha...")
set_with_dataframe(worksheet, df_para_sheets)

print("\nDados exportados com sucesso!")
print(f"Acesse sua planilha aqui: https://docs.google.com/spreadsheets/d/{sh.id}")
# Out:
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# Autenticando para acesso ao Google Sheets...
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-36-3246382283.py in <cell line: 0>()
#      11 # Autentica o usuário para permitir o acesso ao Google Drive/Sheets
#      12 print("\nAutenticando para acesso ao Google Sheets...")
# ---> 13 auth.authenticate_user()
#      14 from google.auth import default
#      15 creds, _ = default()
#
# /usr/local/lib/python3.11/dist-packages/google/colab/auth.py in authenticate_user(clear_output, project_id)
#     258   if not _check_adc(_CredentialType.USER):
#     259     if use_auth_ephem:
# ...

# %% [markdown]
# # Dados EUA

# %%
df_eua_web.to_csv('eua1.csv')
df_eua_web_rf.to_csv('eua2.csv')

# %%
# IDs utilizados pelo yahoo finance EUA
series_ids_yf_eua = {
    'eua_sp500': '^GSPC',        # S&P 500
    'eua_nasdaq': '^IXIC',      # NASDAQ
    'eua_vix': '^VIX',     # Volatilidade (VIX)
}

df_eua_yf = yf.download(list(series_ids_yf_eua.values()), start='2000-01-01', end='2024-12-31')['Close'] #Extraindo com o periodo desejado
df_eua_yf.head()

# %%
#tratando os dados
df_eua_yf.columns = series_ids_yf_eua.keys() #Renomear colunas com ids
df_eua_yf = df_eua_yf.resample('M').last() #trazer apenas ultimo valor do mês (fechamento mensal)
df_eua_yf.index = df_eua_yf.index.to_period('M') #YYYY-MM
df_eua_yf.head()

# %%
# IDs utilizados pelo pandas_datareader EUA
series_ids_web = {
    'eua_juros': 'FEDFUNDS',             # Taxa de juros (Fed)
    'eua_inflacao': 'CPIAUCSL',          # Inflação (CPI)
    'eua_pib': 'GDP',                    # PIB (EUA)
    'eua_tips_breakeven_5y': 'T5YIE',    # Inflação implícita (TIPS)
}

df_eua_web = web.DataReader(list(series_ids_web.values()), 'fred' , start='2000-01-01', end='2024-12-31') #Extraindo com o periodo desejado
df_eua_web.head()

# %%
df_eua_web_rf = df_eua_web

# Renomear as colunas
df_eua_web_rf.columns = series_ids_web.keys()

# Interpolar PIB
df_eua_web_rf['eua_pib'] = df_eua_web_rf['eua_pib'].resample('M').ffill().interpolate(method='linear')

# justar a inflação
df_eua_web_rf['eua_inflacao'] = df_eua_web_rf['eua_inflacao'] / 10000

# 6. Converter o índice para PeriodIndex (passo final do tratamento de datas)
df_eua_web_rf.index = df_eua_web_rf.index.to_period('M')

# Handle duplicate index values by grouping and taking the mean
df_eua_web_rf = df_eua_web_rf.groupby(df_eua_web_rf.index).mean()

# 8. Exibir o resultado final para verificação
print("DataFrame EUA")
display(df_eua_web_rf.head())

# %%
eua_full = pd.concat([df_eua_yf, df_eua_web_rf], axis=1)
eua_full.head()

# %%
#analise basica df
print("Informações gerais da base:\n")
print(f"Linha/Coluna: {eua_full.shape}")
print("\nTipos de dados:")
print(eua_full.dtypes)

print("\n Valores nulos por coluna:")
print(eua_full.isnull().sum())

print("\nEstatísticas descritivas:")
display(eua_full.describe())

# %%
# Análise EUA
eua_corr = eua_full.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(eua_corr, annot=True, cmap='coolwarm', fmt='.2f', center=0)
plt.title('Matriz de Correlação - Indicadores Econômicos EUA')
plt.tight_layout()
plt.show()

# %%
import os
def restart_runtime():
  os.kill(os.getpid(), 9)

restart_runtime()
